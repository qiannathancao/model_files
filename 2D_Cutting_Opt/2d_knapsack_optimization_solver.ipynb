# %%
import pandas as pd
import numpy as np
from rectpack import newPacker
import rectpack.packer as packer
import matplotlib.pyplot as plt
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
from pyspark.sql.types import NullType
import pyspark.sql.functions as F
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# %run "./preprocess"

# %%
def col_name(df):
    """
    this is to trim the data_frame column names to a unique format:
    all case, replace space to underscore, remove parentheses
    param df:
        raw from share drive for
    return:
        polished data set with new column names
    """
    res = [c.strip().lower().replace('-', '').replace(' ', '_').replace('(', '').replace(')', '').replace('"', '') for c in df.columns]
    return res
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
def solver(pal_dim, item_qty, sheet_dim):
  rectangles = [pal_dim for i in range(item_qty)]
  
  # Build the Packer
  pack = newPacker(mode = packer.PackingMode.Offline, bin_algo = packer.PackingBin.Global,
                   rotation=True)

  # Add the rectangles to packing queue
  for r in rectangles:
      pack.add_rect(*r)
      
  # Add the bins where the rectangles will be placed
  for b in sheet_dim:
      pack.add_bin(*b)
      
  # Start packing
  pack.pack()
  
  # Full rectangle list
  all_rects = pack.rect_list()
  
  # Pallets with dimensions
  all_pals = [sorted([p[3], p[4]]) for p in all_rects]
  

  # count number of item cutted
  p_item = all_pals.count(pal_dim)
  
  return p_item
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>form</th><th>alloy</th><th>grade</th><th>specification</th><th>part_on_schedule</th><th>part_number_detail</th><th>vendor</th><th>lower_gaugein</th><th>widthin</th><th>lengthin</th><th>weightlbs</th><th>base_material</th><th>total_weight_st_overall</th></tr></thead><tbody><tr><td>SHEET</td><td>null</td><td>null</td><td>ASTM B209</td><td>null</td><td>0011632</td><td>null</td><td>null</td><td>13</td><td>5.56</td><td>0.64</td><td>null</td><td>null</td></tr><tr><td>SHEET</td><td>null</td><td>null</td><td>SPEC NOT SPECIFIED</td><td>null</td><td>0153203</td><td>null</td><td>null</td><td>32.42</td><td>107</td><td>null</td><td>null</td><td>null</td></tr><tr><td>SHEET</td><td>null</td><td>null</td><td>ASTM B209</td><td>null</td><td>0153942</td><td>null</td><td>null</td><td>29.75</td><td>2</td><td>0.54</td><td>null</td><td>null</td></tr><tr><td>SHEET</td><td>null</td><td>null</td><td>ASTM B209</td><td>null</td><td>0153943</td><td>null</td><td>null</td><td>14.75</td><td>2</td><td>0.27</td><td>null</td><td>null</td></tr><tr><td>SHEET</td><td>null</td><td>null</td><td>ASTM B209</td><td>null</td><td>0153945</td><td>null</td><td>null</td><td>29.88</td><td>29.88</td><td>4.41</td><td>null</td><td>null</td></tr><tr><td>SHEET</td><td>null</td><td>null</td><td>ASTM B209</td><td>null</td><td>0153948</td><td>null</td><td>null</td><td>3</td><td>2</td><td>null</td><td>null</td><td>null</td></tr><tr><td>SHEET</td><td>null</td><td>null</td><td>ASTM B209</td><td>null</td><td>182752</td><td>null</td><td>null</td><td>26</td><td>26</td><td>5.7</td><td>null</td><td>null</td></tr><tr><td>SHEET</td><td>null</td><td>null</td><td>ASTM B209</td><td>null</td><td>182801</td><td>null</td><td>null</td><td>81.9375</td><td>60</td><td>null</td><td>null</td><td>null</td></tr><tr><td>
td></tr></tbody></table></div>
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>materialType</th><th>width</th><th>length</th></tr></thead><tbody><tr><td>SHEET_48120</td><td>48</td><td>120</td></tr><tr><td>SHEET_60120</td><td>60</td><td>120</td></tr><tr><td>SHEET_48144</td><td>48</td><td>144</td></tr><tr><td>SHEET_72144</td><td>72</td><td>144</td></tr></tbody></table></div>

# %% [markdown]
# ##### Opt out to run the following cell - Cmd 11

# %%
# dim_dict = dict(zip(df_dim.materialType, zip(df_dim.width, df_dim.length, df_dim.sheet_size)))
# sheet_size_list = [dim_dict[k][2] for k in dim_dict.keys()]
# temp_df = df_dim.set_index('materialType')
# df_dim_T = pd.DataFrame(temp_df.unstack(level='materialType')).T
# df_dim_T.columns = df_dim_T.columns.map('{0[1]}|{0[0]}'.format)
# df_dim_T.sort_index(axis=1, inplace=True)
# df_fab_dim = df_fab.copy()
# df_fab_dim[df_dim_T.columns] = pd.concat([df_fab, df_dim_T], axis=1)[df_dim_T.columns].ffill()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# def yield_estimate_0(df_1, df_2, _solver):
#   yield_estimate_result = []
#   padding_sheet_as_zeros = sum(~df_2.materialType.str.contains('PLATE'))
#   padding_plate_as_zeros = sum(~df_2.materialType.str.contains('SHEET'))
  
#   df_2_selected_plate = df_2[df_2["materialType"].str.contains('PLATE', na=False)]
#   df_2_selected_sheet = df_2[df_2["materialType"].str.contains('SHEET', na=False)]
  
#   if 'PLATE' in df_1[0]:
#     res = [0] * padding_sheet_as_zeros
    
#     for _, i in df_2_selected_plate.iterrows():
#       sheet_size = i[3]
#       blank_size = df_1[3]
#       max_n = int(sheet_size//blank_size)
#       sheet_dim = np.sort([(i[1], i[2])])
#       pal_dim = np.sort([df_1[1], df_1[2]]).tolist()
#       yield_item_count = _solver(pal_dim, max_n, sheet_dim)
#       yield_estimate_result.append(yield_item_count)  
#     ret = res + yield_estimate_result
  
#   else: 
#     res = [0]*padding_plate_as_zeros
    
#     for _, i in df_2_selected_sheet.iterrows():
#       sheet_size = i[3]
#       blank_size = df_1[3]
#       max_n = int(sheet_size//blank_size)
#       sheet_dim = np.sort([(i[1], i[2])])
#       pal_dim = np.sort([df_1[1], df_1[2]]).tolist()
#       yield_item_count = _solver(pal_dim, max_n, sheet_dim)
#       yield_estimate_result.append(yield_item_count)
#     ret = yield_estimate_result + res    
    
#   return ret
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
def yield_estimate(df_1, df_2, _solver, opt_out_threshold = 200):
  yield_estimate_result = []
  padding_sheet_as_zeros = sum(~df_2.materialType.str.contains('PLATE'))
  padding_plate_as_zeros = sum(~df_2.materialType.str.contains('SHEET'))
  
  df_2_selected_plate = df_2[df_2["materialType"].str.contains('PLATE', na=False)]
  df_2_selected_sheet = df_2[df_2["materialType"].str.contains('SHEET', na=False)]
  
  if 'PLATE' in df_1[0]:
    res = [0] * padding_sheet_as_zeros
    
    for _, i in df_2_selected_plate.iterrows():
      sheet_size = i[3]
      blank_size = df_1[3]
      max_n = int(sheet_size//blank_size)
      sheet_dim = np.sort([(i[1], i[2])])
      pal_dim = np.sort([df_1[1], df_1[2]]).tolist()
      
      if max_n <= opt_out_threshold:
        yield_item_count = _solver(pal_dim, max_n, sheet_dim)
        yield_estimate_result.append(yield_item_count)  
        
      else:
        yield_item_count = max_n 
        yield_estimate_result.append(yield_item_count)
    ret = res + yield_estimate_result
  
  else: 
    res = [0]*padding_plate_as_zeros
    
    for _, i in df_2_selected_sheet.iterrows():
      sheet_size = i[3]
      blank_size = df_1[3]
      max_n = int(sheet_size//blank_size)
      sheet_dim = np.sort([(i[1], i[2])])
      pal_dim = np.sort([df_1[1], df_1[2]]).tolist()
      
      if max_n <= opt_out_threshold:
        yield_item_count = _solver(pal_dim, max_n, sheet_dim)
        yield_estimate_result.append(yield_item_count) 
        
      else:
        yield_item_count = max_n
        yield_estimate_result.append(yield_item_count)
    ret = yield_estimate_result + res    
    
  return ret
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
selected_col = [ 'form', 'widthin', 'lengthin', 'blank_sheet_size']
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
batch_1_start, batch_1_end = 0, 5
batch_2_start, batch_2_end = batch_1_end, 30
batch_3_start, batch_3_end = batch_1_end, 300

batch_load_1 = df_fab[selected_col].iloc[range(batch_1_start,batch_1_end), :]
# batch_load_2 = df_fab[selected_col].loc[range(batch_2_start,batch_2_end), :].drop_duplicates(subset = ['widthin','lengthin'])
batch_load_2 = df_fab[selected_col].loc[range(batch_2_start,batch_2_end), :]
batch_load_3 = df_fab[selected_col].iloc[:, :]
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
df_dim
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[18]: </div>
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>materialType</th>
#       <th>width</th>
#       <th>length</th>
#       <th>sheet_size</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>SHEET_48120</td>
#       <td>48</td>
#       <td>120</td>
#       <td>5760</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>SHEET_60120</td>
#       <td>60</td>
#       <td>120</td>
#       <td>7200</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>SHEET_48144</td>
#       <td>48</td>
#       <td>144</td>
#       <td>6912</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>SHEET_72144</td>
#       <td>72</td>
#       <td>144</td>
#       <td>10368</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
display(df_fab.head())
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>form</th><th>alloy</th><th>grade</th><th>specification</th><th>part_on_schedule</th><th>part_number_detail</th><th>vendor</th><th>lower_gaugein</th><th>widthin</th><th>lengthin</th><th>weightlbs</th><th>base_material</th><th>total_weight_st_overall</th><th>blank_sheet_size</th></tr></thead><tbody><tr><td>SHEET</td><td>null</td><td>null</td><td>ASTM B209</td><td>null</td><td>0011632</td><td>null</td><td>null</td><td>13.0</td><td>5.56</td><td>0.64</td><td>null</td><td>null</td><td>72.28</td></tr><tr><td>SHEET</td><td>null</td><td>null</td><td>SPEC NOT SPECIFIED</td><td>null</td><td>0153203</td><td>null</td><td>null</td><td>32.42</td><td>107.0</td><td>null</td><td>null</td><td>null</td><td>3468.94</td></tr><tr><td>SHEET</td><td>null</td><td>null</td><td>ASTM B209</td><td>null</td><td>0153942</td><td>null</td><td>null</td><td>29.75</td><td>2.0</td><td>0.54</td><td>null</td><td>null</td><td>59.5</td></tr><tr><td>SHEET</td><td>null</td><td>null</td><td>ASTM B209</td><td>null</td><td>0153943</td><td>null</td><td>null</td><td>14.75</td><td>2.0</td><td>0.27</td><td>null</td><td>null</td><td>29.5</td></tr><tr><td>SHEET</td><td>null</td><td>null</td><td>ASTM B209</td><td>null</td><td>0153945</td><td>null</td><td>null</td><td>29.88</td><td>29.88</td><td>4.41</td><td>null</td><td>null</td><td>892.8144</td></tr></tbody></table></div>

# %%
import time
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
batch_load_3
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[21]: </div>
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>form</th>
#       <th>widthin</th>
#       <th>lengthin</th>
#       <th>blank_sheet_size</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>SHEET</td>
#       <td>13.0000</td>
#       <td>5.56</td>
#       <td>72.280000</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>SHEET</td>
#       <td>32.4200</td>
#       <td>107.00</td>
#       <td>3468.940000</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>SHEET</td>
#       <td>29.7500</td>
#       <td>2.00</td>
#       <td>59.500000</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>SHEET</td>
#       <td>14.7500</td>
#       <td>2.00</td>
#       <td>29.500000</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>SHEET</td>
#       <td>29.8800</td>
#       <td>29.88</td>
#       <td>892.814400</td>
#     </tr>
#     <tr>
#       <th>...</th>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#     </tr>
#     <tr>
#       <th>71</th>
#       <td>SHEET</td>
#       <td>43.5000</td>
#       <td>0.75</td>
#       <td>32.625000</td>
#     </tr>
#     <tr>
#       <th>72</th>
#       <td>SHEET</td>
#       <td>60.0000</td>
#       <td>0.75</td>
#       <td>45.000000</td>
#     </tr>
#     <tr>
#       <th>73</th>
#       <td>SHEET</td>
#       <td>94.3125</td>
#       <td>35.25</td>
#       <td>3324.515625</td>
#     </tr>
#     <tr>
#       <th>74</th>
#       <td>SHEET</td>
#       <td>94.3125</td>
#       <td>43.50</td>
#       <td>4102.593750</td>
#     </tr>
#     <tr>
#       <th>75</th>
#       <td>SHEET</td>
#       <td>94.3125</td>
#       <td>60.00</td>
#       <td>5658.750000</td>
#     </tr>
#   </tbody>
# </table>
# <p>76 rows × 4 columns</p>
# </div>

# %%
yield_estimate_result_1 = batch_load_1.apply(lambda x: yield_estimate(x, df_2=df_dim, _solver=solver), axis=1)
yield_estimate_result_1
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[22]: 0        [70, 91, 70, 88, 133]
# 1              [1, 1, 1, 1, 2]
# 2      [96, 120, 96, 108, 166]
# 3    [187, 244, 187, 234, 351]
# 4              [4, 8, 4, 4, 8]
# dtype: object</div>

# %%
yield_estimate_result_2 = batch_load_2.apply(lambda x: yield_estimate(x, df_2=df_dim, _solver=solver), axis=1)
yield_estimate_result_2
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[24]: 5       [960, 1200, 960, 1152, 1728]
# 6                   [4, 8, 4, 5, 10]
# 7                    [0, 1, 0, 0, 1]
# 8               [48, 62, 48, 48, 86]
# 9          [349, 436, 349, 418, 628]
# 10         [349, 436, 349, 418, 628]
# 11    [1316, 1645, 1316, 1579, 2369]
# 12              [30, 36, 30, 36, 43]
# 13              [29, 34, 29, 35, 48]
# 14              [13, 15, 13, 16, 24]
# 15              [13, 15, 13, 16, 24]
# 16         [134, 154, 134, 152, 249]
# 17                  [4, 7, 4, 5, 10]
# 18                  [4, 7, 4, 5, 10]
# 19                  [4, 7, 4, 5, 10]
# 20            [81, 105, 81, 99, 156]
# 21           [94, 119, 94, 116, 168]
# 22         [329, 411, 329, 395, 593]
# 23                   [2, 3, 2, 2, 4]
# 24              [21, 30, 21, 27, 47]
# 25             [60, 70, 60, 73, 102]
# 26             [60, 70, 60, 73, 102]
# 27                   [0, 1, 0, 0, 1]
# 28              [48, 60, 48, 48, 84]
# 29                   [1, 2, 1, 1, 2]
# dtype: object</div>

# %%
yield_estimate_result_3 = batch_load_3.apply(lambda x: yield_estimate(x, df_2=df_dim, _solver=solver, opt_out_threshold=300), axis=1)
yield_estimate_result_3
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[22]: 0        [70, 91, 88, 133]
# 1             [1, 1, 1, 2]
# 2      [96, 120, 108, 166]
# 3     [187, 231, 222, 351]
# 4             [4, 8, 4, 8]
#               ...
# 71    [172, 204, 210, 317]
# 72    [128, 160, 128, 224]
# 73            [1, 1, 1, 2]
# 74            [1, 1, 1, 1]
# 75            [0, 1, 0, 1]
# Length: 76, dtype: object</div>

# %%
new_col = df_dim.materialType.astype('str') + '_yield'
new_col
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[23]: 0    SHEET_48120_yield
# 1    SHEET_60120_yield
# 2    SHEET_48144_yield
# 3    SHEET_72144_yield
# Name: materialType, dtype: object</div>

# %%
test = pd.concat([df_fab.iloc[:, :].reset_index(drop = True), pd.DataFrame(yield_estimate_result_3.tolist(), columns=new_col)], axis=1)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
test
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[25]: </div>
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>form</th>
#       <th>alloy</th>
#       <th>grade</th>
#       <th>specification</th>
#       <th>part_on_schedule</th>
#       <th>part_number_detail</th>
#       <th>vendor</th>
#       <th>lower_gaugein</th>
#       <th>widthin</th>
#       <th>lengthin</th>
#       <th>weightlbs</th>
#       <th>base_material</th>
#       <th>total_weight_st_overall</th>
#       <th>blank_sheet_size</th>
#       <th>SHEET_48120_yield</th>
#       <th>SHEET_60120_yield</th>
#       <th>SHEET_48144_yield</th>
#       <th>SHEET_72144_yield</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>SHEET</td>
#       <td>None</td>
#       <td>None</td>
#       <td>ASTM B209</td>
#       <td>None</td>
#       <td>0011632</td>
#       <td>None</td>
#       <td>None</td>
#       <td>13.0000</td>
#       <td>5.56</td>
#       <td>0.64</td>
#       <td>None</td>
#       <td>None</td>
#       <td>72.280000</td>
#       <td>70</td>
#       <td>91</td>
#       <td>88</td>
#       <td>133</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>SHEET</td>
#       <td>None</td>
#       <td>None</td>
#       <td>SPEC NOT SPECIFIED</td>
#       <td>None</td>
#       <td>0153203</td>
#       <td>None</td>
#       <td>None</td>
#       <td>32.4200</td>
#       <td>107.00</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>3468.940000</td>
#       <td>1</td>
#       <td>1</td>
#       <td>1</td>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>SHEET</td>
#       <td>None</td>
#       <td>None</td>
#       <td>ASTM B209</td>
#       <td>None</td>
#       <td>0153942</td>
#       <td>None</td>
#       <td>None</td>
#       <td>29.7500</td>
#       <td>2.00</td>
#       <td>0.54</td>
#       <td>None</td>
#       <td>None</td>
#       <td>59.500000</td>
#       <td>96</td>
#       <td>120</td>
#       <td>108</td>
#       <td>166</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>SHEET</td>
#       <td>None</td>
#       <td>None</td>
#       <td>ASTM B209</td>
#       <td>None</td>
#       <td>0153943</td>
#       <td>None</td>
#       <td>None</td>
#       <td>14.7500</td>
#       <td>2.00</td>
#       <td>0.27</td>
#       <td>None</td>
#       <td>None</td>
#       <td>29.500000</td>
#       <td>187</td>
#       <td>231</td>
#       <td>222</td>
#       <td>351</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[86]: 0    SHEET_48120_yield_square
# 1    SHEET_60120_yield_square
# 2    SHEET_48144_yield_square
# 3    SHEET_72144_yield_square
# Name: materialType, dtype: object</div>

# %%
start_col_idx = df_dim.shape[0]
temp_square = temp.iloc[:, -start_col_idx:].multiply(temp.blank_sheet_size, axis = 'index')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
list(yield_square_col)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[93]: [&#39;SHEET_48120_yield_square&#39;,
#  &#39;SHEET_60120_yield_square&#39;,
#  &#39;SHEET_48144_yield_square&#39;,
#  &#39;SHEET_72144_yield_square&#39;]</div>

# %%
temp_square.columns = list(yield_square_col)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
temp
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[96]: </div>
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>form</th>
#       <th>alloy</th>
#       <th>grade</th>
#       <th>specification</th>
#       <th>part_on_schedule</th>
#       <th>part_number_detail</th>
#       <th>vendor</th>
#       <th>lower_gaugein</th>
#       <th>widthin</th>
#       <th>lengthin</th>
#       <th>weightlbs</th>
#       <th>base_material</th>
#       <th>total_weight_st_overall</th>
#       <th>blank_sheet_size</th>
#       <th>SHEET_48120_yield</th>
#       <th>SHEET_60120_yield</th>
#       <th>SHEET_48144_yield</th>
#       <th>SHEET_72144_yield</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>SHEET</td>
#       <td>None</td>
#       <td>None</td>
#       <td>ASTM B209</td>
#       <td>None</td>
#       <td>0011632</td>
#       <td>None</td>
#       <td>None</td>
#       <td>13.0000</td>
#       <td>5.56</td>
#       <td>0.64</td>
#       <td>None</td>
#       <td>None</td>
#       <td>72.280000</td>
#       <td>70</td>
#       <td>91</td>
#       <td>88</td>
#       <td>133</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>SHEET</td>
#       <td>None</td>
#       <td>None</td>
#       <td>SPEC NOT SPECIFIED</td>
#       <td>None</td>
#       <td>0153203</td>
#       <td>None</td>
#       <td>None</td>
#       <td>32.4200</td>
#       <td>107.00</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>3468.940000</td>
#       <td>1</td>
#       <td>1</td>
#       <td>1</td>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>SHEET</td>
#       <td>None</td>
#       <td>None</td>
#       <td>ASTM B209</td>
#       <td>None</td>
#       <td>0153942</td>
#       <td>None</td>
#       <td>None</td>
#       <td>29.7500</td>
#       <td>2.00</td>
#       <td>0.54</td>
#       <td>None</td>
#       <td>None</td>
#       <td>59.500000</td>
#       <td>96</td>
#       <td>120</td>
#       <td>108</td>
#       <td>166</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>SHEET</td>
#       <td>None</td>
#       <td>None</td>
#       <td>ASTM B209</td>
#       <td>None</td>
#       <td>0153943</td>
#       <td>None</td>
#       <td>None</td>
#       <td>14.7500</td>
#       <td>2.00</td>
#       <td>0.27</td>
#       <td>None</td>
#       <td>None</td>
#       <td>29.500000</td>
#       <td>187</td>
#       <td>231</td>
#       <td>222</td>
#       <td>351</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>SHEET</td>
#       <td>None</td>
#       <td>None</td>
#       <td>ASTM B209</td>
#       <td>None</td>
#       <td>0153945</td>
#       <td>None</td>
#       <td>None</td>
#       <td>29.8800</td>
#       <td>29.88</td>
#       <td>4.41</td>
#       <td>None</td>
#       <td>None</td>
#       <td>892.814400</td>
#       <td>4</td>
#       <td>8</td>
#       <td>4</td>
#       <td>8</td>
#     </tr>
#     <tr>
#       <th>...</th>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#     </tr>
#     <tr>
#       <th>71</th>
#       <td
td>
#     </tr>
#     <tr>
#       <th>...</th>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#     </tr>
#     <tr>
#       <th>71</th>
#       <td>SHEET</td>
#       <td>None</td>
#       <td>None</td>
#       <td>ASTM B209</td>
#       <td>None</td>
#       <td>MA-41946-02</td>
#       <td>None</td>
#       <td>None</td>
#       <td>43.5000</td>
#       <td>0.75</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>32.625000</td>
#       <td>172</td>
#       <td>204</td>
#       <td>210</td>
#       <td>317</td>
#       <td>5611.500000</td>
#       <td>6655.500000</td>
#       <td>6851.250000</td>
#       <td>10342.12500</td>
#     </tr>
#     <tr>
#       <th>72</th>
#       <td>SHEET</td>
#       <td>None</td>
#       <td>None</td>
#       <td>ASTM B209</td>
#       <td>None</td>
#       <td>MA-41946-03</td>
#       <td>None</td>
#       <td>None</td>
#       <td>60.0000</td>
#       <td>0.75</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>45.000000</td>
#       <td>128</td>
#       <td>160</td>
#       <td>128</td>
#       <td>224</td>
#       <td>5760.000000</td>
#       <td>7200.000000</td>
#       <td>5760.000000</td>
#       <td>10080.00000</td>
#     </tr>
#     <tr>
#       <th>73</th>
#       <td>SHEET</td>
#       <td>None</td>
#       <td>None</td>
#       <td>ASTM B209</td>
#       <td>None</td>
#       <td>MB-41943-01</td>
#       <td>None</td>
#       <td>None</td>
#       <td>94.3125</td>
#       <td>35.25</td>
#       <td>38.28</td>
#       <td>None</td>
#       <td>None</td>
#       <td>3324.515625</td>
#       <td>1</td>
#       <td>1</td>
#       <td>1</td>
#       <td>2</td>
#       <td>3324.515625</td>
#       <td>3324.515625</td>
#       <td>3324.515625</td>
#       <td>6649.03125</td>
#     </tr>
#     <tr>
#       <th>74</th>
#       <td>SHEET</td>
#       <td>None</td>
#       <td>None</td>
#       <td>ASTM B209</td>
#       <td>None</td>
#       <td>MB-41943-02</td>
#       <td>None</td>
#       <td>None</td>
#       <td>94.3125</td>
#       <td>43.50</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>4102.593750</td>
#       <td>1</td>
#       <td>1</td>
#       <td>1</td>
#       <td>1</td>
#       <td>4102.593750</td>
#       <td>4102.593750</td>
#       <td>4102.593750</td>
#       <td>4102.59375</td>
#     </tr>
#     <tr>
#       <th>75</th>
#       <td>SHEET</td>
#       <td>None</td>
#       <td>None</td>
#       <td>ASTM B209</td>
#       <td>None</td>
#       <td>MB-41943-03</td>
#       <td>None</td>
#       <td>None</td>
#       <td>94.3125</td>
#       <td>60.00</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>5658.750000</td>
#       <td>0</td>
#       <td>1</td>
#       <td>0</td>
#       <td>1</td>
#       <td>0.000000</td>
#       <td>5658.750000</td>
#       <td>0.000000</td>
#       <td>5658.75000</td>
#     </tr>
#   </tbody>
# </table>
# <p>76 rows × 22 columns</p>
# </div>

# %%
yield_columns = list(df_fab_with_yield.columns)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
[item for item in yield_columns if yield_columns.count(item) > 1]
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[72]: []</div>

# %%
spark_df_fab_with_yield = spark.createDataFrame(df_fab_with_yield)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
spark_df_fab_with_yield_save = spark_df_fab_with_yield.select([
    F.lit(None).cast('string').alias(i.name)
    if isinstance(i.dataType, NullType)
    else i.name
    for i in spark_df_fab_with_yield.schema
])
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
path = '/mnt/ml/com/dmnd00xxxxx_fabrication_cutting_yield_optimization/input_data/(result)_fabrication_material_sdx_comm.csv'
spark_df_fab_with_yield_save.coalesce(1).write.mode('overwrite').option("header", "true").csv(path)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
df_fab_with_yield['item_qty'] = np.nan_to_num(df_fab_with_yield.sheet_size/df_fab_with_yield.blank_sheet_size).astype(int)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
