# %% [markdown]
# ### Install wheels for Basemap
# - install Proj: https://proj.org/install.html#install
# - go to above link >> find Windows: click OSGeo4W >> download 64bit >> following above link's Window section to isntall PROJ
# - install basemap wheel and pyproj wheel from link: https://www.lfd.uci.edu/~gohlke/pythonlibs/
# - find: Basemap: a matplotlib toolkit for plotting 2D data on maps based on GEOS.
# - find: Pyproj: an interface to the PROJ library for cartographic transformations.
# - #### Important: pip install numpy --upgrade ###

# %% [markdown]
# # ML - Unsupervised Modeling

# %%
# import general packages:
from openpyxl import load_workbook
import win32com.client
import numpy as np
import pandas as pd
from pandas import Grouper
from pandas import Timestamp
import os
import io
import datetime as dt
import time 
import feather
import itertools
from math import sqrt
import csv
import dask.dataframe as dd
from datetime import datetime
import timestring
from IPython.core.display import display, HTML
from collections import defaultdict

# import modeling packages
from sklearn.cluster import AffinityPropagation
from sklearn.cluster import KMeans
from sklearn import preprocessing, datasets
from sklearn.metrics import pairwise_distances_argmin
from scipy.spatial.distance import cdist,pdist
from scipy import stats
from scipy.sparse import *
from collections import Counter

# import visualization packages:
from matplotlib import pyplot as plt
# from mpl_toolkits.basemap import Basemap
import seaborn as sns
# import ggplot
# %matplotlib inline

# checking path and dir
os.chdir('C:\\Users\\u279014\\Documents\\H_Drive\\7.AA Models\\12.Logistic_Optimization\\data')
os.getcwd()
# Out:
# 'C:\\Users\\u279014\\Documents\\H_Drive\\7.AA Models\\12.Logistic_Optimization\\data'

# %%
def riding_distance(riding_distance_matrix, geo):
    """
    Compute a distance matrix of the coordinates using a spherical metric.
    :param  
        coordinate_df: numpy.ndarray with shape (n,n); riding_distance_matri: dataframe, col & index type: str 
        geo_zipcode: Data.Series, element type: str
    :returns distance_mat: numpy.ndarray with shape (n, n) containing distance in km between coords.
    """
    d_matrix = []
    zipcodes = geo['zip_code']
    for i in zipcodes:
        d_row = []
        for j in zipcodes:
            d_row.append(riding_distance_matrix.loc[i,j])
        d_matrix.append(d_row)
    return np.asarray(d_matrix)

# %%
def load_riding_distance_matrix(path,file):
    riding_distance_matrix = pd.read_excel(os.path.join(path,file)).set_index('zipcode')
    riding_distance_matrix.columns = riding_distance_matrix.columns.astype('str')
    riding_distance_matrix.index = riding_distance_matrix.index.astype('str')
    return riding_distance_matrix

# %%
# def distance_on_sphere_numpy(coordinate_df):
#     """
#     Compute a distance matrix of the coordinates using a spherical metric.
#     :param coordinate_array: numpy.ndarray with shape (n,2); latitude is in 1st col, longitude in 2nd.
#     :returns distance_mat: numpy.ndarray with shape (n, n) containing distance in km between coords.
#     """
#     # Radius of the earth in km (GRS 80-Ellipsoid)
#     EARTH_RADIUS = 6371.007176
#     km2mile_ratio = 0.62137

#     # Unpacking coordinates
#     latitudes = coordinate_df.loc[:,'latitude']
#     longitudes = coordinate_df.loc[:,'longitude']

#     # Convert latitude and longitude to spherical coordinates in radians.
#     degrees_to_radians = np.pi/180.0
#     phi_values = (90.0 - latitudes)*degrees_to_radians
#     theta_values = longitudes*degrees_to_radians

#     # Expand phi_values and theta_values into grids
#     theta_1, theta_2 = np.meshgrid(theta_values, theta_values)
#     theta_diff_mat = theta_1 - theta_2

#     phi_1, phi_2 = np.meshgrid(phi_values, phi_values)

#     # Compute spherical distance from spherical coordinates
#     angle = (np.sin(phi_1) * np.sin(phi_2) * np.cos(theta_diff_mat) + 
#            np.cos(phi_1) * np.cos(phi_2))
#     arc = np.arccos(angle)

#     # Multiply by earth's radius to obtain distance in km
#     return np.nan_to_num(arc * EARTH_RADIUS * km2mile_ratio)

# %%
# standardize dataframe colume names
def col_name(df):
    """
    this is to trim the data_frame column names to a unique format:
    all case, replace space to underscore, remove parentheses
    param df:
        raw from share drive for
    return:
        polished data set with new column names
    """
    df.columns = df.columns.str.strip().str.lower().str.replace('-','').str.replace(' ', '_').str.replace('(', '').\
                    str.replace(')', '').str.replace('"','')
    return df

# %%
# covert time format from str to timestamp
def str2time(x):
    """
    paramter 
        x: string formated time
    return: 
        timeStamp with mm/dd/yyyy format 
    """
    try: 
        return datetime.strptime(x,'%b %d, %Y')
    except:
        return '0000-00-00'

# %%
# numpy not support multiple logic, this conducts 3 logic binary
def logic_and_3_condition(x1,x2,x3):
    return np.logical_and(np.logical_and(x1,x2),x3)

# %%
# public source zipcode format standaraization
def clean_zip(file_path = None):
    """
    this is to clean the zip file: 
        - corrdinate format
        - save file as feather format
    
    parameter:
        df: original zipcode msater file 
        file_path: zipcode file directory
        
    return:
        zipcode feather format
    """
    # change zipcodes which contain alphabix letter to 0 (outside of USA)
    def to_string(x):
        try:
            return str(x)
        except:
            return 0   
        
    zipcode = pd.read_csv(file_path)
    zipcode = col_name(zipcode)
    zipcode['zip_code'] = zipcode['zip_code'].apply(lambda x: to_string(x))
    # save to feather format so fast processing
    zipcode.to_feather('zipcode_feather')
    
    return feather.read_dataframe ('zipcode_feather')

# %%
""" Slice shipper_zipcode_region """
def clean_cass2(file_path, 
                source_state=None, 
                dest_zip = '54942', 
                shipping_date_start = '2018-10-01', 
                shipping_window = 7,
                truck_mode = 'LT'):
    """
    parameter: 
        df: dataFrame, original dataset downloaded from cass
        source_state: str, comma needed, default 'WI' as the largest shipping from
        dest_zip: str, default 54942 as greenville
        shipping_date_start: str, starting shipping schedule cut-off date
        shipping_window: int, days out as shipping period window
        truck_mode: str, no comma needed, default LT for less than truck and full truck both inclusive
        
    return:
        df: cleaned dataFrame
    """
    df = pd.read_csv(file_path, low_memory = False)
    df = col_name(df)
    df = df[['source_weekend_date','mode','shipper_name',
       'shipper_address', 'shipper_city', 'shipper_zip', 'shipper_state',
       'destination_city', 'destination_zip', 'destination_state',
       'bill_of_lading_number', 'ship_weight','miles','billed_amount']]
    df = df[df.destination_zip == dest_zip]
    df['ship_weight']=df.ship_weight.apply(lambda x: x.replace(',','')).astype('int') 

    if source_state and source_state is not 'all':
        states = source_state.split(',')
        df = df[np.logical_and(df.destination_zip == dest_zip,df.shipper_state.isin(states))]
    
    df['shipping_date'] = df.source_weekend_date.apply(lambda x: str2time(x))
    df = df[logic_and_3_condition((df.shipping_date >= shipping_date_start),
                           (df.shipping_date - dt.timedelta(shipping_window) <= shipping_date_start),
                           (df['mode'].isin(list(truck_mode))))]  
    df['miles'] = df.miles.apply(lambda x: x.replace(',','')).astype('int')
    df['billed_amount'] = df.billed_amount.apply(lambda x: x.replace(',','')).astype('float')
    
    # change zipcodes which contain alphabix letter to 0 (outside of USA)
    def to_string(x):
        try:
            return str(x)
        except:
            return 0  
    df['shipper_zip'] = df['shipper_zip'].apply(lambda x: to_string(x))    
    return df.reset_index(drop = True)

# %%
def cass_merge_zip(df_cass,df_zip):
    """
    parameter:
        df1: cleaned cass dataset
        df2: original zipcode matrix
        
    return:
        merged dataFrame contains longitude and latitude
    """

    df = pd.merge(df_cass,df_zip[['zip_code','longitude','latitude']],how='left',left_on='shipper_zip', right_on='zip_code')
    df = df.groupby(['zip_code','longitude','latitude','cluster','shipper_name','shipper_state'])['ship_weight','miles','billed_amount'].sum()  
    df.dropna(inplace = True)
    df.reset_index(inplace = True)
    df.to_feather('cass_zip')
    return feather.read_dataframe('cass_zip')

# %%
zipcode_path = r'C:\\Users\\u279014\\Documents\\H_Drive\\7.AA Models\\12.Logistic_Optimization\\data\\zipcode_Lon_Lat.csv'
zipcode = clean_zip(zipcode_path)

# %% [markdown]
# # Modeling Param: by State

# %%
cass_path = r'C:\\Users\\u279014\\Documents\\H_Drive\\7.AA Models\\12.Logistic_Optimization\\data\\Cass FY19 Invoice Detail.csv'
dfcass = clean_cass2(cass_path,shipping_date_start='2019-01-01',shipping_window=360,source_state='WI,IL,MI,IN',truck_mode='TL')

# %%
_data = col_name(pd.read_csv(cass_path, low_memory = False))

# %%
_data = _data[_data.inbound_outbound_indicator == 'INBOUND']

# %%
# data = data[data['destination_city'].isin(['MILWAUKEE', 'GREENVILLE', 'OSHKOSH'])]

# %%
data_mini = data.head(100).append(data.tail(100))

# %%
_data.destination_city.unique()
# Out:
# array(['LAS VEGAS', 'SHIPPENSBURG', 'CHAMBERSBURG', 'ELIZABETH',
#        'NORTH LAS VE', 'GREENCASTLE', 'MCCONNELLSBU', 'BEDFORD',
#        'FAIRBURN', 'MILWAUKEE', 'HOUSTON', 'RIVERSIDE', 'SOUTH BEND',
#        'TERRE HAUTE', 'ORRVILLE', 'LAREDO', 'HAGERSTOWN', 'BLAIR',
#        'GARNER', 'ST ALBERT', 'LONDON', 'AYLMER', 'SURREY', 'SAANICHTON',
#        'COLTON', 'MORGANTOWN', 'DODGE CENTER', 'VILLA RICA', 'FT WAYNE',
#        'HUTCHINS', 'EAST GRANBY', 'RICEVILLE', 'WEST CHESTER',
#        'FAIRFIELD', 'SUGAR GROVE', 'FORT WAYNE', 'LAKELAND',
#        'WEST VALLEY', 'GAHANNA', 'OSHKOSH', 'MCINTIRE', 'PHOENIX', 'LEON',
#        'GREENVILLE', 'TEMECULA', 'DEPERE', 'WEST BEND', 'OAK CREEK',
#        'APPLETON', 'BEAVER DAM', 'CLEARWATER', 'KEWAUNEE', 'BRADENTON',
#        'NEENAH', 'WEYAUWEGA', 'SAINT-LAUREN', 'AJAX', 'DELTA',
#        'W VALLEY CIT', 'E GRANBY', 'WAUKAU', 'WARFORDSBURG', 'QUEBEC',
#        'SAINT LAUREN', 'LETHBRIDGE', 'BRONX', 'EAST GRANDBY', 'DARTMOUTH',
#        'TRURO', 'EDMONTON', 'MISSISSAUGA', 'STAFFORD', 'CALGARY',
#        'JEFFERSON CI', 'MAPLE', 'SALT LAKE CI', 'ST THOMAS',
#        'SAINT JEAN S', 'HARLEY', 'LACHENAIE', 'WOOSTER', 'INGERSOLL',
#        'ST JOHNS', 'GATINEAU', 'SPRINGFIELD', 'ST LAURENT', 'BERLIN',
#        'HIRAM', 'TIANJIN', 'LAVAL', 'UNKNOWN', 'TORONTO', 'SARASOTA',
#        'LUCAN', 'AUDUBON', 'ABERDEEN PRO', 'TWELVE POINT', 'SAINT ALBERT',
#        'EVERETT', 'WARREN', 'SUDBURY', 'ST MARYS'], dtype=object)

# %%
osk_hub_dict = defaultdict(set)
supplier_wh_dict = defaultdict(set)

# %%
dest_list = ['MILWAUKEE', 'OSHKOSH', 'GREENVILLE']

# %%
for sn, dc in zip(_data.shipper_name, _data.destination_city):
    if dc in dest_list:
        osk_hub_dict[sn].add(dc)
    else: 
        pass

# %%
sorted(osk_hub_dict.keys())
# Out:
# ['3752 EATON F',
#  '3769P EATON',
#  '4 WINDS',
#  '5064 EATON E',
#  '7108 SHONA D',
#  'A & I PRODUC',
#  'A A R INC',
#  'A D C METAL',
#  'A T AND F',
#  'A TO Z MACHINE COMPANY, INC.',
#  'A&A MANUFACTURING COMPANY, INC.',
#  'A. R. LINTERN',
#  'A.L. HANSEN MANUFACTURING CO.',
#  'AAR CADILLAC',
#  'AAR CORP',
#  'AARROWCAST, INC.',
#  'ABERDEEN TES',
#  'ABF FREIGHT',
#  'ABL LIGHTS I',
#  'ABLE MANUFACTURING & ASSEMBLY, LLC.',
#  'ACCU-TECH AG',
#  'ACCURIDE',
#  'ACCURIDE COR',
#  'ACCURIDE DIS',
#  'ACCURIDE ERI',
#  'ACCURIDE WHE',
#  'ACD FINISHIN',
#  'ACEM INDUSTR',
#  'ACME INDUSTRIES',
#  'ACME TOOL AN',
#  'ACME TOOLS',
#  'ACTIA CORP',
#  'ACTIA CORPOR',
#  'ACTIVE GEAR',
#  'ACTUANT POWE',
#  'ACTUANT-POWE',
#  'ACUREN',
#  'ADAVANCED LA',
#  'ADC FINISHIN',
#  'ADC FINISHNG',
#  'ADC METAL FI',
#  'ADV FINISHIN',
#  'ADVANCE AUTO PARTS',
#  'ADVANCE WHEE',
#  'ADVANCED COATINGS, INC.',
#  'ADVANCED LASER MACHINING, INC.',
#  'ADVANCED MIL',
#  'AERO INDUSTR',
#  'AEROFAST INC',
#  'AEROPRO, LLC',
#  'AETIA',
#  'AETNA SCREW',
#  'AF TECHNOLOG',
#  'AGILITY ABU',
#  'AIR BOSS FLE',
#  'AIR WAY MANU',
#  'AIRMASTER FA',
#  'AKG NORTH AM',
#  'AKG SD',
#  'AKZENT',
#  'AKZO NOBEL C',
#  'ALACRIANT MF',
#  'ALBION INDUS',
#  'ALCOA',
#  'ALCOA C O TE',
#  'ALCOA C/O TE',
#  'ALCOA CO TER',
#  'ALCOA TEMINA',
#  'ALDINI LDA',
#  'ALDOA',
#  'ALL FREIGHT',
#  'ALL LIFT CRA',
#  'ALL LIFT SYS',
#  'ALL LIFTS SY',
#  'ALL STATE BE',
#  'ALL STATE IN',
#  'ALL STATES I',
#  'ALL-LIFT SYS',
#  'ALL-STATE IN',
#  'ALLAN INDUSTRIAL COATINGS',
#  'ALLEGIS CORPORATION',
#  'ALLIANCE IND',
#  'ALLIANCE MFG',
#  'ALLIED CHART',
#  'ALLIED CHECK',
#  'ALLIED CHUCK',
#  'ALLIED INDUS',
#  'ALLISON TRANSMISSION, INC.',
#  'ALLOY SLING',
#  'ALM POSITION',
#  'ALM POSITITI',
#  'ALMOND PRODUCTS',
#  'ALPINE PRODU',
#  'AMEREX CORPORATION',
#  'AMERI-KART CORPORATION',
#  'AMERICAN COOLING SYSTEMS LLC',
#  'AMERICAN CUS',
#  'AMERICAN MET',
#  'AMERICAN POW',
#  'AMERICAN TAN',
#  'AMERLINE ENT',
#  'AMPHIBIOUS V',
#  'AMSAFE',
#  'ANCRA INTERN',
#  'ANDALE READY',
#  'ANDERSON PUM',
#  'ANSUL FIRE P',
#  'APEX TOOL GROUP, LLC',
#  'API HEAT TRA',
#  'APPLETON PAC',
#  'APPLIED FAB',
#  'APPLIED INDUSTRIAL TECHNOLOGIES',
#  'APPLIED POWER PRODUCTS',
#  'APPLIED PROC',
#  'APPLIED SPEC',
#  'APPLIEDINDUS',
#  'APT CNC',
#  'APT CNC % DO',
#  'APT CNC/DOTS',
#  'APX ENCLOSUR',
#  'APX TOOL GRO',
#  'AR LATERN IN',
#  'ARCONIC',
#  'ARDMORE BRAK',
#  'ARENS',
#  'ARENS CONTROLS COMPANY, LLC',
#  'ARGONICS',
#  'ARGONICS, INC.',
#  'ARM ASHEVILL',
#  'ARM LAURINBU',
#  'ARM ORK IO',
#  'ARM SHEVILLE',
#  'ARM YORK',
#  'ARM YORK IO',
#  'ARMOR METAL',
#  'ARMY BASE FO',
#  'ARTISAN INDUSTRIES, INC.',
#  'ARVIN AUTOMO',
#  'ASC',
#  'ASC INDUSTRIES, INC.',
#  'ASPEN SYSTEM',
#  'ASSOC SPRING',
#  'ASSOCIATED B',
#  'ASSOCIATED F',
#  'ASSOCIATED M',
#  'ASSOCIATED S',
#  'ATACO STEEL',
#  'ATAP INC',
#  'ATC LIGHT &',
#  'ATC LIGHT PL',
#  'ATC LIGHTING',
#  'AURORA BEARING COMPANY',
#  'AURORA CORD & CABLE COMPANY',
#  'AURORA MANUFACTURING, INC.',
#  'AURORA NORTH AMERICA, INC.',
#  'AURORA WELDING & FABRICATION, INC',
#  'AUSA RFK STA',
#  'AUTO-JET MUF',
#  'AVON BEARING',
#  'AXLETECH INTERNATIONAL',
#  'B & H INDUST',
#  'BADGER MILL SUPPLY CORPORATION',
#  'BADGER TRUCK',
#  'BAGBY GAGE S',
#  'BAKER MANUFA',
#  'BAKER MFG',
#  'BALDEX INC',
#  'BALDWIN FILT',
#  'BANDIX CVS L',
#  'BANK TECHNOL',
#  'BANK TECNOLO',
#  'BANKS TECHNO',
#  'BANNER WELDE',
#  'BANNER WELDI',
#  'BARCAR MFG',
#  'BARRETT DIST',
#  'BARRY CONTROLS',
#  'BEHNKE WAREH',
#  'BENDIX COMMERCIAL VEHICLE SYSTEMS LLC',
#  'BENDIX CVS I',
#  'BENDX',
#  'BENT TUBES, LLC',
#  'BENTLEY WORL',
#  'BERGSTOM CAD',
#  'BERGSTROM AUTOMOTIVE',
#  'BERGSTROM, INC.',
#  'BERNTSEN',
#  'BERNTSEN FOU',
#  'BERRY CONTRO',
#  'BETA FUELING',
#  'BETTS INDUST',
#  'BETTS SPRING',
#  'BEYOND VISIO',
#  'BEYOND-VISIO',
#  'BIG SANDY RA',
#  'BILL SHEPPAR',
#  'BILSTEIN NOR',
#  'BLACHFORD',
#  'BLACHFORD AM',
#  'BLACHFORD IN',
#  'BLAHFORD AM',
#  'BLAST CLEANI',
#  'BLUCO CORPOR',
#  'BNSF',
#  'BNSF RAILWAY',
#  'BOOMERANG',
#  'BOOMERANG RU',
#  'BORGWARNER A',
#  'BORGWARNER M',
#  'BORGWARNER P',
#  'BORGWARNER, INC.',
#  'BOSCH AUTOMO',
#  'BOSCH REXROTH',
#  'BOSTROM SEAT',
#  'BRANSON ULTR',
#  'BREMEN CASTI',
#  'BRENNAN EQUI',
#  'BRENNAN INDUSTRIES, INC.',
#  'BRETON INDUS',
#  'BRIAN WEIMER',
#  'BRICKHAM MAC',
#  'BRICKHAM STA',
#  'BRIGHTON MAC',
#  'BRIGHTON NC',
#  'BUCHER INDUSTRIES AG',
#  'BUCKBOARD IN',
#  'BUFFERS USA, INC.',
#  'BULL MOOSE',
#  'BULL MOOSE E',
#  'BULL MOSSE E',
#  'BURKARD INDUSTRIES',
#  'BUYERS PRODUCTS COMPANY',
#  'C & M FORWAR',
#  'C M FORWARDI',
#  'C M WAREHOUS',
#  'C.E. NIEHOFF & CO.',
#  'CABLE MOORE',
#  'CALDWELL GRO',
#  'CAMP PENDLET',
#  'CANNON MACHI',
#  'CARDINAL COM',
#  'CARDINAL FOR',
#  'CAREW CONCRE',
#  'CARGO TEC US',
#  'CARGOTEC USA',
#  'CARGOTEE USA',
#  'CARLTON BATE',
#  'CAROTEC USA',
#  'CASCADE CANA',
#  'CAST TECHNOL',
#  'CATERPILLAR, INC.',
#  'CCE NIEHOFF',
#  'CENTERLINE M',
#  'CENTRO INC',
#  'CENTURY FOUN',
#  'CERTIFIED POWER INC.',
#  'CEVA FREIGHT',
#  'CEVA LOGISTI',
#  'CEVAFREIGHT',
#  'CHALMER SUSP',
#  'CHALMERS',
#  'CHALMERS SUS',
#  'CHAMPION CHA',
#  'CHAMPION CO',
#  'CHAMPION CO.',
#  'CHAMPION GSE',
#  'CHANNEL DIST',
#  'CHARGEPOINT',
#  'CHEMSTATION',
#  'CHICAGO EXEC',
#  'CIMAC SHEEL',
#  'CIMAC WHEEL',
#  'CIRCLE GEAR',
#  'CLA VAL',
#  'CLA VAL COMP',
#  'CLAMPCO PROD',
#  'CLAMPS INC',
#  'CLEMCO INDUS',
#  'CLEVELAND BR',
#  'CLIMAX METAL',
#  'CM AUTOMOTIV',
#  'CN HARVEY',
#  'COFFING HOIS',
#  'COLONIAL SUR',
#  'COLORADO CON',
#  'COLUMBUS',
#  'COLUMBUS MCKINNON CORPORATION',
#  'COMMANDING',
#  'COMMANDING O',
#  'COMMERCIAL VEHICLE GROUP, INC.',
#  'COMPAK INC /',
#  'COMPONENT ENGINEERING, INC.',
#  'CON GLOBAL',
#  'CON WAY FREI',
#  'CONTINENTAL',
#  'CONWAY FREIG',
#  'COOPER BUSSM',
#  'COPE PLASTIC, INC.',
#  'CORWN BATTER',
#  'COTTERMAN CO',
#  'CPRS BENSENV',
#  'CREATIVE MICROSYSTEMS',
#  'CRENLO',
#  'CRENLO INC',
#  'CRESHELN PRO',
#  'CROSBY GROUP',
#  'CROSBY MCKIS',
#  'CROUSE-HINDS',
#  'CROWN BATTER',
#  'CRYSTAL MANU',
#  'CSX 59TH',
#  'CSX 71ST',
#  'CSX BEDFORD',
#  'CSX INTERMOD',
#  'CTECH MANUFA',
#  'CTP',
#  'CTP CORPORAT',
#  'CUMMINS',
#  'CUMMINS FILI',
#  'CUMMINS, INC.',
#  'CURTISS WRIGHT CONTROLS',
#  'CUSTOM FABRI',
#  'CUSTOM FIBER',
#  'CUSTOM FIRBE',
#  'CUSTOME FIBE',
#  'CUSTOMS FIBE',
#  'CVG DEVICES',
#  'CVG SPRAGE D',
#  'CVG SPRAUGE',
#  'D AND S MFG',
#  'D L GEORGE A',
#  'D S MFG',
#  'D W INDUSTRI',
#  'D&S MANUFACTURING, INC.',
#  'D&S MFG',
#  'DAEWOO INTER',
#  'DAFG CO DANA',
#  'DAK EQUIPMEN',
#  'DALA DE MEXI',
#  'DANA CANADA',
#  'DANA CORP HE',
#  'DANA DISTRIB',
#  'DANA HOLDING CORPORATION',
#  'DANA LAFAYET',
#  'DANA MANUFAC',
#  'DANFOSS POWER SOLUTIONS',
#  'DANTRONICS',
#  'DANTRONICS I',
#  'DANTRONICS%S',
#  'DATA DELTA C',
#  'DATA DEVICE',
#  'DATA DEVISCE',
#  'DAYCO',
#  'DAYCO PRODUC',
#  'DAYTON FREIG',
#  'DAYTON PARTS',
#  'DCI',
#  'DEERE & COMPANY',
#  'DEFEENSE SOU',
#  'DEFENCES OF',
#  'DEFENSE',
#  'DEFENSE LOGI',
#  'DEFENSE SOUT',
#  'DEFENSE WEST',
#  'DEFIANCE METAL PRODUCTS',
#  'DEFLECT-O CO',
#  'DEFLECTO',
#  'DEFLECTO LLC',
#  'DEINES NEITZ',
#  'DEINES NITZ',
#  'DEINES-NITZ',
#  'DEKALB FORGE',
#  'DEKALBE FARG',
#  'DELAND MFG',
#  'DELTA POWER COMPANY',
#  'DEPERE FOUND',
#  'DETROIT ARSE',
#  'DETROIT DIESEL',
#  'DEVRIES INTE',
#  'DEWALD FLUID',
#  'DIALIGHT DE',
#  'DIGITAL SYST',
#  'DISTRIBUTION',
#  'DIXIE INDUST',
#  'DJS MANUFACTURING, INC.',
#  'DONALDSON COMPANY, INC.',
#  'DONALDSON DO',
#  'DORNER MFG C',
#  'DOTSON COMPA',
#  'DOTSON COMPANY',
#  'DOUGLAS AUTOTECH CORPORATION',
#  'DREISON INTE',
#  'DRESSER ARGU',
#  'DS ENTERPRIS',
#  'DS MFG',
#  'DUBOIS CHEMICALS, INC.',
#  'DUERCAROLINA',
#  'DUNCAN DISTR',
#  'DUNHAM RUBBER & BELTING CORP',
#  'DURABLE USA',
#  'DURST CORP',
#  'DUSTCONTROL',
#  'DUTTON LAINS',
#  'DW INDUSTRIE',
#  'DYNAMIC METALS, LLC',
#  'DYNATECT GOR',
#  'DYNATECT MFG',
#  'DYNETICS',
#  'E B FUSION',
#  'E.H. BAARE CORP.',
#  'EAGLE ALLOY',
#  'EAGLE PERFOR',
#  'EAST IOWA MACHINE COMPANY',
#  'EATON BUSSMA',
#  'EATON CORPORATION PLC',
#  'EATON ELECTR',
#  'EATON HYD EF',
#  'EATON HYD PO',
#  'EATON IND MF',
#  'EATON-VICKER',
#  'EATONS BUSSM',
#  'EB FUSION',
#  'EBCO INCORPORATED',
#  'EBERHARD MANUFACTURING COMPANY',
#  'EBS PRODUCTS',
#  'EBU LAGRANGE',
#  'ECCO',
#  'ECS COMPOSIT',
#  'EELCTRON BEA',
#  'EH BAAR CORP',
#  'EHBAAR',
#  'ELECTION BEA',
#  'ELECTRICAL C',
#  'ELECTRON BEA',
#  'ELECTRONIC COATING TECHNOLOGIES',
#  'ELITE COATI',
#  'ELITE COATIN',
#  'ELKHART BRASS MANUFACTURING COMPANY, INC.',
#  'ELKHART PLAS',
#  'ELLSWORTH AD',
#  'EMTECH',
#  'EMTECH INC',
#  'ENERGYS ENER',
#  'ENERSYS',
#  'ENERSYS DELA',
#  'ENERSYS ENER',
#  'ENGINE POWER',
#  'ENGINEERED C',
#  'ENVIRONMENTA',
#  'EPIC RESINS',
#  'ETM ENTERPRI',
#  'EUBANKS ENGI',
#  'EUROFINS MET',
#  'EUROLINK INC',
#  'EXDIE TECHNO',
#  'EXIDE TECHNOLOGIES',
#  'EXPEDITORS INTERNATIONAL',
#  'FABCO EQUIPM',
#  'FABICK',
#  'FABICK EQUIP',
#  'FABRIFAST LLC',
#  'FAIRCHILD IN',
#  'FAIRFIELD MANUFACTURING COMPANY, INC.',
#  'FALL PROTECT',
#  'FASTENAL',
#  'FASTENAL CO',
#  'FASTENAL COM',
#  'FASTENAL COR',
#  'FAURECIA EMI',
#  'FAURECIA POL',
#  'FED EX',
#  'FED EX TERMI',
#  'FEDERAL MOGU',
#  'FEDERAL SIGN',
#  'FEDERAL WARE',
#  'FEDEX FREIGH',
#  'FEDEX TERMIN',
#  'FEDTECH, INC.',
#  'FEMCO MACHIN',
#  'FIAMM TECHNO',
#  'FIBER TECH',
#  'FIBER-TECH',
#  'FIBERDOME',
#  'FIBERDOME IN',
#  'FIEX N GATE',
#  'FIRESTONE IN',
#  'FIRETRACE AE',
#  'FIRST SUPPLY',
#  'FLAMBEAU COR',
#  'FLAMBEAU INC',
#  'FLAMBEAU PLA',
#  'FLEET ENGINE',
#  'FLEX-N-GATE CORPORATION',
#  'FLEXIBLE PRO',
#  'FLODRAULIC G',
#  'FLUID LINE P',
#  'FLUID POWER, INC.',
#  'FLUID PROCES',
#  'FLUID SYSTEM COMPONENTS, INC.',
#  'FONDY AUTO E',
#  'FORCE AMERIC',
#  'FORT BENNING',
#  'FOX VALLEY H',
#  'FOX VALLEY M',
#  'FREER TOOL A',
#  'FSIP INDIANA',
#  'FT BRADD USA',
#  'FT BRAGG USA',
#  'FT MCCOY LAF',
#  'G & W PRODUC',
#  'G AND T INDU',
#  'GABRIEL RIDE CONTROL, LLC',
#  'GALE BANKS E',
#  'GALLAGHER CO',
#  'GALLMAR INDU',
#  'GARDMER MFG',
#  'GARDNER MANUFACTURING, INC.',
#  'GARFIELD WAR',
#  'GARNER MFG',
#  'GARNER WI',
#  'GARRETT ADVA',
#  'GATES CORPORATION',
#  'GATEWAY CABL',
#  'GAYLORD NATI',
#  'GCI',
#  'GCI ENGINEER',
#  'GEMINI PLAST',
#  'GENERAL DEVI',
#  'GENERAL DYNA',
#  'GENERAL FAST',
#  'GENERAL KINE',
#  'GENERAL META',
#  'GENERAL TRUC',
#  'GENERLA KINE',
#  'GENMET CORPORATION',
#  'GEOLEAN USA',
#  'GEORGE UTZ',
#  'GEORGE W MOR',
#  'GEORGIA PACI',
#  'GGB NORTH AM',
#  'GH MANUFACTU',
#  'GKN DRIVE TE',
#  'GKN DRIVELIN',
#  'GKN DRIVETEC',
#  'GKN ROCKFORD',
#  'GKN WALTERSC',
#  'GLENERAL KIN',
#  'GLOBAL 4',
#  'GLOBAL COMPO',
#  'GLOBAL INDUS',
#  'GLOBETECH',
#  'GLOBETECH MA',
#  'GLOBETECH MF',
#  'GO LIGHT INC',
#  'GOETTGE MEMO',
#  'GOLDBERG COM',
#  'GONZALES',
#  'GONZALEZ',
#  'GONZALEZ PRO',
#  'GOODRIDGE US',
#  'GORBEL',
#  'GORBEL CO CM',
#  'GORBEL INC',
#  'GORDON ALUMI',
#  'GORMAN RUPP',
#  'GORMAN-RUPP',
#  'GRADNER MFG',
#  'GRAND RIVER FABRICATING',
#  'GRANITE CORP',
#  'GRAY MANUFAC',
#  'GREAT LAKCS',
#  'GREAT LAKES',
#  'GREHELN PROD',
#  'GREY MFG',
#  'GRIESBACH RE',
#  'GRIFFITH RUB',
#  'GROTE INDUST',
#  'GS GLOBAL RESOURCES, INC.',
#  'GS HYDRAULICS, INC.',
#  'GUNITE CORPORATION',
#  'GUNITE ROCKF',
#  'H O BOSTROM',
#  'H-P PRODUCTS, INC.',
#  'HAAS AUTOMAT',
#  'HADLEY PRODU',
#  'HALDEX AB',
#  'HANNAY REELS, INC.',
#  'HANSEN INTERNATIONAL, INC.',
#  'HARDNER MFG',
#  'HARDWIRE',
#  'HARRINGTON H',
#  'HARRIS MACHINE COMPANY',
#  'HARTFORD FIN',
#  'HASTINGS AIR',
#  'HAYES INDUST',
#  'HAYS FABRICA',
#  'HB PERFORMAN',
#  'HBM SHERMAN',
#  'HDT VEHICLE',
#  'HEALE MANUFA',
#  'HEALE MFG CO',
#  'HEARTLAND ST',
#  'HEATBATH',
#  'HELGESEN INDUSTRIES, INC.',
#  'HENDERSON AU',
#  'HENDRICKSON',
#  'HENKEL CORPORATION',
#  'HENKEL US OP',
#  'HENKEL WARRE',
#  'HENRICKSON S',
#  'HENRICKSON T',
#  'HENTZEN COATINGS, INC.',
#  'HERBERT ORR',
#  'HERITAGE INDUSTRIAL FINISHING',
#  'HESS READY M',
#  'HODGES TRANS',
#  'HOLLAND USA',
#  'HORIZON GLOB',
#  'HORTON HOLDING, INC.',
#  'HORTON INDUS',
#  'HUB CITY',
#  'HURON AUTOMA',
#  'HUSCO INTERNATIONAL, INC.',
#  'HUSKEY RACK',
#  'HUSKY RACK A',
#  'HUTCHINSON C',
#  'HUTCHINSON I',
#  'HUTCHINSON S',
#  'HYDAC INTERNATIONAL',
#  'HYDRAULIC &',
#  'HYDRAULIC VA',
#  'HYDRO ELECTR',
#  'I A P INC',
#  'IAP INC',
#  'IBIS TCK',
#  'IBIS TEK',
#  'IBIS TEK LLC',
#  'ICAFE',
#  'IFH GROUP',
#  'ILLINOIS FOR',
#  'IMMI',
#  'IMPREX',
#  'IMT',
#  'INDIANA LOGI',
#  'INDIANA MILLS & MANUFACTURING, INC.',
#  'INDUS HOLDING AG',
#  'INDUSTRIAL E',
#  'INDUSTRIAL F',
#  'INDUSTRIAL N',
#  'INGERSOLL RA',
#  'INNOVATIVE F',
#  'INNOVATIVE M',
#  'INSUL-FAB',
#  'INSULFAB',
#  'INSULTECH CO',
#  'INTERSTATE P',
#  'INTEVA PRODU',
#  'IOW MOLD TOO',
#  'IOWA MOLD TO',
#  'IOWA MOLD TR',
#  'ISSPRO',
#  'ISSPRO INC',
#  'ISSPRO INCOR',
#  'ITT CORPORAT',
#  'ITT KONI',
#  'ITT KONI AME',
#  'J & D TUBE B',
#  'J AMD M MACH',
#  'J D LASER IN',
#  'J D TUBE B',
#  'J G B ENTERP',
#  'J M GRIMSTAD',
#  'J STADLER MACHINE, INC.',
#  'J TEC INDUST',
#  'J&M MACHINE PRODUCTS, INC.',
#  'J&R MACHINE, INC.',
#  'J.W. SPEAKER CORPORATION',
#  'JACK PHELAN',
#  'JAE CUSTOM T',
#  'JANKEL TACTI',
#  'JARP INDUSTRIES, INC.',
#  'JARP REMAN F',
#  'JASPER RUBBE',
#  'JAY MANUFACTURING OSHKOSH, INC.',
#  'JBM MORSE RD',
#  'JBM SHERMAN',
#  'JD LASER',
#  'JD LASER INC',
#  'JESCO INDUST',
#  'JET MACHINE',
#  'JGB ENTEPRIS',
#  'JGB ENTERPRI',
#  'JGB METROPOL',
#  'JGP ENTERPRI',
#  'JIMS RECYCIN',
#  'JLG',
#  'JLG IND',
#  'JLG TUBE BEN',
#  'JLTV RETROFI',
#  'JM GRIMSTAD',
#  'JOHN DEER CO',
#  'JOHN JOHNSON COMPANY',
#  'JOHNSON CONTROLS, INC.',
#  'JOHNSON WELDED PRODUCTS, INC.',
#  'JONES METAL',
#  'JOR-MAC COMPANY, INC.',
#  'JOST INTERNA',
#  'JTV MANUFACT',
#  'JTV MFG INC',
#  'JULIAN ELECTRIC, INC.',
#  'JUST IN TIME CORPORATION',
#  'JWP',
#  'KAMMERER',
#  'KAMMERER FAB',
#  'KAPCO, INC.',
#  'KAWASAKI',
#  'KAYDON BEARI',
#  'KBRWYLELL TE',
#  'KD LAMP',
#  'KD LAMP PIER',
#  'KD LAMPHTING',
#  'KEN S SPORTS',
#  'KEN TOOL',
#  'KEN-TOOLS',
#  'KENAKORE SOL',
#  'KEWAUNEE FAB',
#  'KEWAUNEE FAL',
#  'KEWAUNEE FAR',
#  'KEWEENAW RES',
#  'KEWUANEE FAB',
#  'KHYSSEN KRUP',
#  'KINETIC TECH',
#  'KNORR BREMSE',
#  'KOCHEK CO',
#  'KOCHEK SPECI',
#  'KONGSBERG AU',
#  'KOYO BEARING',
#  'KR WEST CO I',
#  'KRC MICHICGA',
#  'KRC MICHIGAN',
#  'KRISRY INTER',
#  'KUKU AUTOMAT',
#  'KUNDINGER FL',
#  'KUWAIT MINIS',
#  'L & S TRUCK',
#  'L S TRUCK CE',
#  'L&S TRUCK CE',
#  'LACAY',
#  'LAFARGEHOLCI',
#  'LAMBEAU FIEL',
#  'LANDOLL CORP',
#  'LANGHAM LOGI',
#  'LAPHAM-HICKEY STEEL CORPORATION',
#  'LASER SHOP',
#  'LASER SHOP I',
#  'LB STEEL CO',
#  'LB STEEL INC',
#  'LB STEEL, LLC',
#  'LE SUEUR INC',
#  'LEECO STEEL, LLC',
#  'LEESON ELECT',
#  'LEHIGH VALLEY PLASTICS, INC.',
#  'LETOURNEAU P',
#  'LIEBHERR USA',
#  'LIFT-ALL COM',
#  'LIFTPRO',
#  'LIGHTING PRO',
#  'LIGON INDUST',
#  'LINCOLNTON B',
#  'LINDCO INC',
#  'LINEMASTER S',
#  'LINFOR INC',
#  'LINK MFG LTD',
#  'LIQUID CONTR',
#  'LOC PERFORMA',
#  'LOG PARK',
#  'LOGAN CLUTCH',
#  'LONDON MACHI',
#  'LONGWOOD',
#  'LONGWOOD ELA',
#  'LOUISVILLE L',
#  'LUCERIX INTE',
#  'LYCO MANUFAC',
#  'MAANITOWAC C',
#  'MACHINE SERVICES, INC.',
#  'MAITOWOC',
#  'MALEY LASER',
#  'MALONE SPECI',
#  'MANATOWOC CR',
#  'MANITEWOC',
#  'MANITEX, INC.',
#  'MANITOWAC CR',
#  'MANITOWOC COMPANY (THE)',
#  'MANITOWOC RE',
#  'MANITOWOC TOOL & MANUFACTURING',
#  'MANITWAC CRA',
#  'MARADYNE',
#  'MARADYNE COR',
#  'MARDYNE',
#  'MARINE FASTE',
#  'MARIOIN BODY',
#  'MARION BODF',
#  'MARION BODY WORKS, INC.',
#  'MARLIN TECHN',
#  'MARMON HERRI',
#  'MARSH ELECTR',
#  'MARTEK POWER',
#  'MASSLOAD TEC',
#  'MATCON',
#  'MATERIAL CEN',
#  'MATERIAL CON',
#  'MAXIMA TECHN',
#  'MAXION WHEEL',
#  'MAYVILLE ENGINEERING COMPANY, INC.',
#  'MCCLARIN PLASTICS, INC.',
#  'MCCORD PAYEN',
#  'MCL ENGINEER',
#  'MCL INDUSTRIES, INC.',
#  'MCMASTER CAR',
#  'MCMASTER-CAR',
#  'MCNBEILUS TR',
#  'MCNEILUS',
#  'MCNEILUS AFT',
#  'MCNEILUS BRA',
#  'MCNEILUS CEN',
#  'MCNEILUS COM',
#  'MCNEILUS COR',
#  'MCNEILUS PAR',
#  'MCNEILUS STE',
#  'MCNEILUS TRU',
#  'MCNEIULS',
#  'MCNILUS TRUC',
#  'MEC',
#  'MEC ATKINS',
#  'MEC ATKINS V',
#  'MEC COATINGS',
#  'MEDALLION INSTRUMENATION SYSTEMS, LLC',
#  'MEDATECH ENG',
#  'MEFRO WHEELS',
#  'MERCURY ELEC',
#  'MERCURY METAL PRODUCTS',
#  'MERCURY SYST',
#  'MERITOR - YO',
#  'MERITOR FORE',
#  'MERITOR LLC',
#  'MERITOR WABCO',
#  'MERITOR YORK',
#  'MERITOR, INC.',
#  'METAL FINISH',
#  'METAL PRODUCTS, INC.',
#  'METAL SPINNE',
#  'METALCRAFT OF MAYVILLE, INC.',
#  'METALCUT PRODUCTS, INC.',
#  'METALSA',
#  'METALSA SA D',
#  'METHOD INNOV',
#  'METL CUT PRO',
#  'METRO AIRPOR',
#  'METRO WHEELS',
#  'MGM BRAKES',
#  'MI TECH KRC',
#  'MICHIGAN FOR',
#  'MICHIGAN TEC',
#  'MICO, INC.',
#  'MID CONTINEN',
#  'MID-AMERICAN',
#  'MID-CONTINEN',
#  'MIDDLE EAST',
#  'MIDDLE WEST',
#  'MIDLAND PLASTICS, INC.',
#  'MIDSTATES',
#  'MIDWEST CAST',
#  'MIDWEST FINI',
#  'MIDWEST HARN',
#  'MIDWEST MOTO',
#  'MIDWEST RUBE',
#  'MIDWEST SPEC',
#  'MIDWEST TU B',
#  'MIDWEST TUBE FABRICATION, INC.',
#  'MII EQUIPMEN',
#  'MILCUT, INC.',
#  'MILLER WELDING & MACHINE',
#  'MILLERBERND SYSTEMS, INC.',
#  'MILSCO MANUFACTURING COMPANY',
#  'MILTON IND I',
#  'MILTON MANUF',
#  'MILWAUKEE OS',
#  'MILWAUKEE PA',
#  'MINER ENTERP',
#  'MINNEAPOLIS',
#  'MISSION RUBB',
#  'MIT TERMINAL',
#  'MITCHELL RUB',
#  'MOBILE CLIMATE CONTROL',
#  'MODERN INDUS',
#  'MODINE INDUS',
#  'MODINE MANFA',
#  'MODINE MANUFACTURING COMPANY',
#  'MODINE TRENT',
#  'MODINEER COMPANY',
#  'MOLDED PLASTIC INDUSTRIES',
#  'MONARCH INDU',
#  'MONONA WA',
#  'MONROE TRUCK',
#  'MOTION INDUS',
#  'MOVEX INC',
#  'MSC INDUSTRI',
#  'MSI DEFENSE',
#  'MSSL WIRING',
#  'MUNCY CORPORATION',
#  'MUZA METAL PRODUCTS',
#  'MWA',
#  'N M TRANSPOR',
#  'N.E.W. INDUSTRIES, INC.',
#  'NACA LOGISTI',
#  'NALDEX INC',
#  'NASHVILLE WI',
#  'NATC OSHKOSH',
#  'NATIONAL EXP',
#  'NATIONAL SEATING COMPANY',
#  'NATIONAL TEC',
#  'NEAPCO',
#  'NELSON GLOBAL PRODUCTS, INC.',
#  'NEVADA AUTOM',
#  'NEW AGE INDU',
#  'NEW TECH METALS',
#  'NOLTES LLC',
#  'NOMA APPLIAN',
#  'NORCO INDUST',
#  'NORD GEAR CO',
#  'NORDFAB',
#  'NORFOLK SOUT',
#  'NORLEN, INC.',
#  'NORR BREMSE',
#  'NORRIS CYLIN',
#  'NORTH AMERIC',
#  'NORTHERN IRON AND MACHINE',
#  'NORTHERN TOO',
#  'NORTHLAND ST',
#  'NOTT COMPANY',
#  'NS CHICAGO',
#  'NTN BEARING',
#  'NTN BOWER CO',
#  'NTN BOWER-MA',
#  'NTN BRG CORP',
#  'NU CALGON IN',
#  'OAKWOOD GROU',
#  'OAKWOOD META',
#  'OC NORTH PLA',
#  'OEM FABRICATORS, INC.',
#  'OHIO TRC',
#  'OILDYNE',
#  'OLON INDUSTR',
#  'OMNI GLASS & PAINT, INC.',
#  'OPTIMAS OE S',
#  'ORAM SAFETY',
#  'ORAN SAFETY GLASS, INC.',
#  'ORAN SAFFETY',
#  'ORAN SAFTEY',
#  'ORAN SAFTY G',
#  'ORBIS CORP',
#  'ORBIS CORPOR',
#  'ORBIS MENASH',
#  'ORLACO INC',
#  'ORSCHEIN PRO',
#  'ORSCHELA',
#  'ORSCHELA PRO',
#  'ORSCHELN PRODUCTS, LLC',
#  'ORSHELM PROD',
#  'ORSHELN PROD',
#  'OS RETRAC',
#  'OSG INCORPOR',
#  'OSH DEF K VO',
#  'OSH DEF LLC',
#  'OSH DEF REDS',
#  'OSH DEF T AN',
#  'OSHKOSH',
#  'OSHKOSH - DE',
#  'OSHKOSH - GL',
#  'OSHKOSH COIL',
#  'OSHKOSH CORP',
#  'OSHKOSH DEFE',
#  'OSHKOSH FIRE',
#  'OSHKOSH LARE',
#  'OSHKOSH MANF',
#  'OSHKOSH MANU',
#  'OSHKOSH MARI',
#  'OSHKOSH NORT',
#  'OSHKOSH PART',
#  'OSHKOSH PLAT',
#  'OSHKOSH TENT',
#  'OSHKOSH TRUC',
#  'P W PLATFORM',
#  'PAC TEC',
#  'PAC TEC INC',
#  'PACBRAKE',
#  'PACBRAKE CO',
#  'PACBRAKE COM',
#  'PACBRAKE MAN',
#  'PACIFIC DIES',
#  ...]

# %%
def get_cluster(state):
    if state in ['WI','IL','MI','IN']:
        return 'mid_west'
    elif state in ['PA','NY','MD']:
        return 'north_east'
    elif state in ['NC','SC','GA']:
        return 'south_east'
    return 'other'
    
dfcass['cluster'] = dfcass.shipper_state.apply(get_cluster)
dfcass.to_csv(r'C:\Users\u279014\Documents\H_Drive\7.AA Models\12.Logistic_Optimization\data\supplier_clustering.csv',index=False)
dfcass.shipper_zip.to_excel(r'C:\Users\u279014\Documents\H_Drive\7.AA Models\12.Logistic_Optimization\data\PCMiller\zipcodes.xlsx',
                            sheet_name='Sheet1',header = False,index = False)

# %%
### Distance Matrix: to replaced by using PCM_Riding Distance Matrix
cass_zip = cass_merge_zip(dfcass,zipcode)
cass_zip.to_csv(r'C:\Users\u279014\Documents\H_Drive\7.AA Models\12.Logistic_Optimization\data\suppliers_geo.csv')
##### To run PCM API for riding distance #####
# Out:
# C:\Users\U279014\Anaconda3\lib\site-packages\ipykernel_launcher.py:12: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   if sys.path[0] == '':

# %% [markdown]
# # Clustering Modeling: Supplier by Region Modeling (Kmeans, DBSCAN)
# ### Solution 1: KMeans_Modeling
# - #### Using euclidean distance based geograpthic infomation and historical volume to cluser suppliers by zipcode in region
# - #### Clustering metrix: ‘cosine’, ‘euclidean’[default], ‘l1’, ‘l2’,

# %%
from sklearn.cluster import KMeans
from collections import Counter

# %%
geo = cass_zip.loc[:,['longitude','latitude']]
X = np.array(geo)

# %%
plt.figure(figsize=(20,20))
mm = Basemap(llcrnrlon = min(X[:,0])-15,llcrnrlat = min(X[:,1]-10), urcrnrlon = max(X[:,0]+10),urcrnrlat = max(X[:,1]+10))
# mm.drawmapboundary(fill_color = '#A6CAE0',linewidth = 0)
mm.fillcontinents(color = 'grey', alpha = 0.3, lake_color = 'black')
mm.drawcoastlines(linewidth = 0.5,color = 'white')

mm.shadedrelief()
mm.drawcoastlines(color='gray')
mm.drawcountries(color='gray')
mm.drawstates(color='gray')


plt.scatter(X[:,0],X[:,1],s=200,cmap='viridis',c='blue')
plt.show()

# %%
distortions = []
K = range(1,20)
for k in K:
    kmeans = KMeans(n_clusters=k, random_state=0).fit(geo)
    distortions.append(sum(np.min(cdist(geo,kmeans.cluster_centers_,'euclidean'),axis=1))/geo.shape[0])

df_distortion = pd.DataFrame(distortions,columns=['sum_square_distances_to_center'])
df_distortion.to_csv(r'C:\Users\u279014\Documents\H_Drive\7.AA Models\12.Logistic_Optimization\data\k_selection.csv',index='No_cluster')  

    # Plot the elbow
plt.plot(K, distortions, 'bx-')
plt.xlabel('k')
plt.ylabel('Distortion')
plt.title('The Elbow Method showing the optimal k')
plt.show()

# %%
df_distortion['distortion_moving_diff'] = df_distortion.sum_square_distances_to_center.diff(-1)

# %%
plt.plot(K, df_distortion.distortion_moving_diff, 'bx-')
plt.xlabel('k')
plt.ylabel('Distortion_DIFF')
plt.title('The Elbow Method showing the optimal k')
plt.show()

# %%
df_distortion.to_csv(r'C:\Users\u279014\Documents\H_Drive\7.AA Models\12.Logistic_Optimization\data\k_selection.csv',index='No_cluster')

# %%
id_n=8
kmeans = KMeans(n_clusters=id_n, random_state=0).fit(geo)
id_label=kmeans.labels_
kmeans_centers = kmeans.cluster_centers_

# %%
geo_cass = cass_zip
geo_cass['label'] = kmeans.labels_
geo_cass.to_csv(r'C:\Users\u279014\Documents\H_Drive\7.AA Models\12.Logistic_Optimization\data\geo_cass.csv',index=False)

# %%
plt.figure(figsize=(20,20))
mm = Basemap(llcrnrlon = min(kmeans_centers[:,0])-15,llcrnrlat = min(kmeans_centers[:,1]-10), 
             urcrnrlon = max(kmeans_centers[:,0]+10),urcrnrlat = max(kmeans_centers[:,1]+10))
mm.fillcontinents(color = 'grey', alpha = 0.3, lake_color = 'black')
mm.drawcoastlines(linewidth = 0.5,color = 'white')

mm.shadedrelief()
mm.drawcoastlines(color='gray')
mm.drawcountries(color='gray')
mm.drawstates(color='gray')

plt.scatter(kmeans_centers[:,0],kmeans_centers[:,1],s=200,cmap='viridis',c='blue')
plt.show()

# %% [markdown]
# ### Solution 2: DBSCAN_Modeling:
# ####  - advantange: calculates gap distance limitation & precomputed distance matrix gives more flexibilit
# #### -  weakness: not mentioning where to be center

# %%
from sklearn.cluster import DBSCAN
from scipy.spatial.distance import pdist, squareform

# %%
s = 'WI,IL'

# %%
if not isinstance(s, list):
    new_s = s.split(',')

# %%
new_s
# Out:
# ['WI', 'IL']

# %%
cluster_selections = ['WI','IL','MI','IN','IA','MI']
geo = cass_zip[cass_zip.shipper_state.isin(cluster_selections)].reset_index()

# %%
type(geo.zip_code[0])
# Out:
# str

# %%
# distance_matrix = distance_on_sphere_numpy(geo)

# %% [markdown]
# ### Distance_Matrix using actual riding distance >>>>

# %%
path = r'C:\Users\u279014\Documents\H_Drive\7.AA Models\12.Logistic_Optimization\data'
file = r'riding_distance_matrix.xlsx'
riding_distance_matrix = load_riding_distance_matrix(path,file)
distance_matrix = riding_distance(riding_distance_matrix, geo)

# %%
np.any(riding_distance_matrix.columns == '53012')
# Out:
# True

# %%
"""
parameter:
    eps: location to core distance in between
    min_samples: minimum locations in one group(cluster)
    metric: precomputed as we have our own distance metricx
return:
    cluster model
"""
db = DBSCAN(eps=20,min_samples=3,metric='precomputed',leaf_size=30)
db.fit(distance_matrix)
# Out:
# DBSCAN(eps=20, metric='precomputed', min_samples=3)

# %%
# Save csv for PowerBI visualization
geo['label']=db.labels_
geo.to_csv('cass_zip_cluster.csv',index=False)
geo.to_feather('cass_zip_cluster')
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pyarrow\feather.py:85: FutureWarning: The SparseDataFrame class is removed from pandas. Accessing it from the top-level namespace will also be removed in the next version
#   if isinstance(df, _pandas_api.pd.SparseDataFrame):

# %%
# let's take a look which cluster has most locations:
counter = Counter(db.labels_)
counter.most_common()
# Out:
# [(-1, 52),
#  (6, 30),
#  (12, 9),
#  (8, 7),
#  (0, 6),
#  (10, 6),
#  (1, 5),
#  (2, 5),
#  (5, 5),
#  (3, 4),
#  (4, 3),
#  (7, 3),
#  (9, 3),
#  (11, 3)]

# %% [markdown]
# ## Now, go to PowerBi for Reviewing >>>>>>>
