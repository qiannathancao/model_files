# %%
DATA_PATH = '/mnt/ml/prc/inventory_management/dmnd0013915_def_inventory_management/SS_batch_upload_0217.csv'

EOQ_DATA_PATH = '/mnt/ml/prc/inventory_management/dmnd0013915_def_inventory_management/eoq_dataset'
# DELTA_STORAGE_PATH = '/mnt/ml/prc/inventory_management/dmnd0013915_def_inventory_management/ss_fr'

SMOOTH_DEMAND_TABLE = 'training.dmnd0013915_defense_demand_smoothed'
SAFETY_STOCK = 'training.dmnd0013915_defense_safety_stock_result'
SAFETY_STOCK_FILLRATE =  'training.dmnd0013915_defense_safety_stock_result_fill_rate'

RESULT_SS_FR_CSV = '/mnt/ml/prc/inventory_management/dmnd0013915_def_inventory_management/SS_batch_upload_0217_result.csv'



REVIEW_CYCLE = 1
CYCLE_SERVICE_LEVEL = 0.9

vop_bound = [7, 84]
DEF_carrying_financial_rate = 0.073
EAU_CALENDER_DAYS = 320
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
